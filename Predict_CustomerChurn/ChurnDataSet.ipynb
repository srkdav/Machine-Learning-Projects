# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('./telecom.csv')

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.shape
# Out:
# (3333, 20)

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df['Churn'] = df['Churn'].astype('int64')

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.describe(include=['object','bool'])
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
df['Churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# 0    0.855086
# 1    0.144914
# Name: Churn, dtype: float64

# %%
df.sort_values('Total day charge',ascending=True)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1345    SD              98        415                 No              No
# 1397    VT             101        510                 No              No
# 2736    OK             127        510                 No             Yes
# 2753    OH             134        415                 No              No
# 1986    WI              70        415                 No              No
# ...    ...             ...        ...                ...             ...
# 605     MO             112        415                 No              No
# 156     OH              83        415                 No              No
# 2594    OH             115        510                Yes              No
# 985     NY              64        415                Yes              No
# 365     CO             154        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.sort_values('Total day charge',ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 365                       0              350.8               75
# 985                       0              346.8               55
# 2594                      0              345.3               81
# 156                       0              337.4              120
# 605                       0              335.5               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.sort_values(by=['Total day charge','Total eve charge'],ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 365                       0              350.8               75
# 985                       0              346.8               55
# 2594                      0              345.3               81
# 156                       0              337.4              120
# 605                       0              335.5               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df['Churn'].mean()
# Out:
# 0.14491449144914492

# %%
df[df['Churn']==1].median()
# Out:
# Account length            103.00
# Area code                 415.00
# Number vmail messages       0.00
# Total day minutes         217.60
# Total day calls           103.00
# Total day charge           36.99
# Total eve minutes         211.30
# Total eve calls           101.00
# Total eve charge           17.96
# Total night minutes       204.80
# Total night calls         100.00
# Total night charge          9.22
# Total intl minutes         10.60
# Total intl calls            4.00
# Total intl charge           2.86
# Customer service calls      2.00
# Churn                       1.00
# dtype: float64

# %%
df[df['Churn']==1].mean()
# Out:
# Account length            102.664596
# Area code                 437.817805
# Number vmail messages       5.115942
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %%
df[df['Churn']==1]['Total day minutes'].mean()
# Out:
# 206.91407867494814

# %%
df[(df['Churn']==0)& (df['International plan']=='No')]['Total intl minutes'].max()
# Out:
# 18.9

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.loc[:5,'State':'Area code']
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415
# 5    AL             118        510

# %%
df[df['State'].apply(lambda state:state[0]=='W')]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 9       WV             141        415                Yes             Yes
# 26      WY              57        408                 No             Yes
# 44      WI              64        510                 No              No
# 49      WY              97        415                 No             Yes
# 54      WY              87        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3278    WI              87        415                 No              No
# 3303    WI             114        415                 No             Yes
# 3319    WY              89        415                 No              No
# 3324    WV             159        415                 No              No
# 3329    WV              68        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.groupby(by='Churn')['Total day minutes', 'Total eve minutes', 
                   'Total night minutes'].describe()
# Out:
# <ipython-input-46-bea3f3582015>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by='Churn')['Total day minutes', 'Total eve minutes',
#       Total day minutes                                                      \
#                   count        mean        std  min      25%    50%     75%
# Churn
# 0                2850.0  175.175754  50.181655  0.0  142.825  177.2  210.30
# 1                 483.0  206.914079  68.997792  0.0  153.250  217.6  265.95
#
#              Total eve minutes              ...                 \
#          max             count        mean  ...     75%    max
# Churn                                       ...
# 0      315.6            2850.0  199.043298  ...  233.20  361.8
# 1      350.8             483.0  212.410145  ...  249.45  363.7
#
#       Total night minutes                                               \
# ...

# %%
pd.crosstab(df['Churn'],df['Voice mail plan'],normalize=True)
# Out:
# Voice mail plan        No       Yes
# Churn
# 0                0.602460  0.252625
# 1                0.120912  0.024002
